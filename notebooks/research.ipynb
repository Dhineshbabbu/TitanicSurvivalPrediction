# %% [markdown]
# # 1 Import Libraries

# %%
# !pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.12-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from lazypredict) (1.2.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from lazypredict) (2.2.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from lazypredict) (4.66.1)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from lazypredict) (1.4.0)
# Requirement already satisfied: lightgbm in /opt/conda/lib/python3.10/site-packages (from lazypredict) (4.2.0)
# Requirement already satisfied: xgboost in /opt/conda/lib/python3.10/site-packages (from lazypredict) (2.0.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from lightgbm->lazypredict) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from lightgbm->lazypredict) (1.11.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->lazypredict) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->lazypredict) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->lazypredict) (2023.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->lazypredict) (3.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->lazypredict) (1.16.0)
# Downloading lazypredict-0.2.12-py2.py3-none-any.whl (12 kB)
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.2.12

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import chi2
from sklearn.preprocessing import LabelEncoder
from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split
import optuna
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

# %%
train_df=pd.read_csv('/kaggle/input/titanic/train.csv')
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male 22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female 38.00      1
# 2                               Heikkinen, Miss. Laina  female 26.00      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.00      1
# 4                             Allen, Mr. William Henry    male 35.00      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male 27.00      0
# 887                       Graham, Miss. Margaret Edith  female 19.00      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male 26.00      0
# 890                                Dooley, Mr. Patrick    male 32.00      0
#
#      Parch            Ticket  Fare Cabin Embarked
# 0        0         A/5 21171  7.25   NaN        S
# 1        0          PC 17599 71.28   C85        C
# 2        0  STON/O2. 3101282  7.92   NaN        S
# 3        0            113803 53.10  C123        S
# 4        0            373450  8.05   NaN        S
# ..     ...               ...   ...   ...      ...
# 886      0            211536 13.00   NaN        S
# 887      0            112053 30.00   B42        S
# 888      2        W./C. 6607 23.45   NaN        S
# 889      0            111369 30.00  C148        C
# 890      0            370376  7.75   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# # 2 EDA Process

# %%
train_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### Age, cabin and Embarked are missing values

# %%
train_df[['Age','Cabin','Embarked']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       714 non-null    float64
#  1   Cabin     204 non-null    object
#  2   Embarked  889 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 21.0+ KB

# %%
len(train_df['Cabin'].unique()),train_df.shape[0]
# Out:
# (148, 891)

# %%
train_df['Age'].describe()
# Out:
# count   714.00
# mean     29.70
# std      14.53
# min       0.42
# 25%      20.12
# 50%      28.00
# 75%      38.00
# max      80.00
# Name: Age, dtype: float64

# %% [markdown]
# ### 1. Age (numerical variable) feature has outliers so replace the null values with median
# ### 2. Cabin and Embarked are categorical vaiable so replace wth mode

# %% [markdown]
# ## 2.1 Replace NULL values

# %%
train_df.fillna({'Age':train_df['Age'].median()},inplace=True)
train_df.fillna({'Cabin':train_df['Cabin'].mode().iloc[0]},inplace=True)
train_df.fillna({'Embarked':train_df['Embarked'].mode().iloc[0]},inplace=True)
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male 22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female 38.00      1
# 2                               Heikkinen, Miss. Laina  female 26.00      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.00      1
# 4                             Allen, Mr. William Henry    male 35.00      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male 27.00      0
# 887                       Graham, Miss. Margaret Edith  female 19.00      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female 28.00      1
# 889                              Behr, Mr. Karl Howell    male 26.00      0
# 890                                Dooley, Mr. Patrick    male 32.00      0
#
#      Parch            Ticket  Fare    Cabin Embarked
# 0        0         A/5 21171  7.25  B96 B98        S
# 1        0          PC 17599 71.28      C85        C
# 2        0  STON/O2. 3101282  7.92  B96 B98        S
# 3        0            113803 53.10     C123        S
# 4        0            373450  8.05  B96 B98        S
# ..     ...               ...   ...      ...      ...
# 886      0            211536 13.00  B96 B98        S
# 887      0            112053 30.00      B42        S
# 888      2        W./C. 6607 23.45  B96 B98        S
# 889      0            111369 30.00     C148        C
# 890      0            370376  7.75  B96 B98        Q
#
# [891 rows x 12 columns]

# %%
train_df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_df['Age'].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ### Perform Label Encodeing

# %%
encoder=LabelEncoder()
def label_encoder(col):
    if col.dtypes=='object':
        col=encoder.fit_transform(col)
    return col

# %%
train_df=train_df.apply(lambda col:label_encoder(col))
train_df
# Out:
#      PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket  \
# 0              1         0       3   108    1 22.00      1      0     523
# 1              2         1       1   190    0 38.00      1      0     596
# 2              3         1       3   353    0 26.00      0      0     669
# 3              4         1       1   272    0 35.00      1      0      49
# 4              5         0       3    15    1 35.00      0      0     472
# ..           ...       ...     ...   ...  ...   ...    ...    ...     ...
# 886          887         0       2   548    1 27.00      0      0     101
# 887          888         1       1   303    0 19.00      0      0      14
# 888          889         0       3   413    0 28.00      1      2     675
# 889          890         1       1    81    1 26.00      0      0       8
# 890          891         0       3   220    1 32.00      0      0     466
#
#      Fare  Cabin  Embarked
# 0    7.25     47         2
# 1   71.28     81         0
# 2    7.92     47         2
# 3   53.10     55         2
# 4    8.05     47         2
# ..    ...    ...       ...
# 886 13.00     47         2
# 887 30.00     30         2
# 888 23.45     47         2
# 889 30.00     60         0
# 890  7.75     47         1
#
# [891 rows x 12 columns]

# %% [markdown]
# ## 2.2 Feature Selection

# %%
X=train_df.drop(['Survived'],axis=1)
y=train_df['Survived']

# %%
f_p_value=chi2(X,y)

# %%
p_value=pd.Series(f_p_value[1])
p_value.index=X.columns
p_value.sort_index(ascending=True)
# Out:
# Age           0.00
# Cabin         0.00
# Embarked      0.00
# Fare          0.00
# Name          0.00
# Parch         0.00
# PassengerId   0.07
# Pclass        0.00
# Sex           0.00
# SibSp         0.11
# Ticket        0.00
# dtype: float64

# %% [markdown]
# ### Ticket,sibsp corelate less to the output variable
# ### So delete the Ticket,sibsp from dataframe

# %%
train_df.drop(['Ticket','SibSp'],axis=1,inplace=True)
train_df
# Out:
#      PassengerId  Survived  Pclass  Name  Sex   Age  Parch  Fare  Cabin  \
# 0              1         0       3   108    1 22.00      0  7.25     47
# 1              2         1       1   190    0 38.00      0 71.28     81
# 2              3         1       3   353    0 26.00      0  7.92     47
# 3              4         1       1   272    0 35.00      0 53.10     55
# 4              5         0       3    15    1 35.00      0  8.05     47
# ..           ...       ...     ...   ...  ...   ...    ...   ...    ...
# 886          887         0       2   548    1 27.00      0 13.00     47
# 887          888         1       1   303    0 19.00      0 30.00     30
# 888          889         0       3   413    0 28.00      2 23.45     47
# 889          890         1       1    81    1 26.00      0 30.00     60
# 890          891         0       3   220    1 32.00      0  7.75     47
#
#      Embarked
# 0           2
# 1           0
# 2           2
# 3           2
# 4           2
# ..        ...
# 886         2
# 887         2
# 888         2
# 889         0
# 890         1
#
# [891 rows x 10 columns]

# %% [markdown]
# # 3 Model Selection

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=123)

# %%
Classifier=LazyClassifier()
model,predict=Classifier.fit(X_train,X_test,y_train,y_test)
model
# Out:
# 100%|██████████| 29/29 [00:02<00:00, 13.85it/s]
# [LightGBM] [Info] Number of positive: 244, number of negative: 379
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003221 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 865
# [LightGBM] [Info] Number of data points in the train set: 623, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.391653 -> initscore=-0.440368
# [LightGBM] [Info] Start training from score -0.440368
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# XGBClassifier                      0.85               0.84     0.84      0.85
# AdaBoostClassifier                 0.85               0.83     0.83      0.85
# LGBMClassifier                     0.84               0.82     0.82      0.84
# KNeighborsClassifier               0.83               0.82     0.82      0.83
# RandomForestClassifier             0.83               0.81     0.81      0.83
# SVC                                0.82               0.80     0.80      0.82
# NuSVC                              0.82               0.80     0.80      0.82
# ExtraTreesClassifier               0.82               0.80     0.80      0.82
# BaggingClassifier                  0.82               0.79     0.79      0.82
# NearestCentroid                    0.79               0.79     0.79      0.79
# LogisticRegression                 0.80               0.79     0.79      0.80
# QuadraticDiscriminantAnalysis      0.80               0.78     0.78      0.80
# LinearSVC                          0.80               0.78     0.78      0.80
# DecisionTreeClassifier             0.80               0.78     0.78      0.80
# LinearDiscriminantAnalysis         0.80               0.78     0.78      0.80
# GaussianNB                         0.80               0.78     0.78      0.80
# RidgeClassifier                    0.80               0.78     0.78      0.80
# RidgeClassifierCV                  0.80               0.78     0.78      0.80
# CalibratedClassifierCV             0.80               0.78     0.78      0.80
# BernoulliNB                        0.79               0.78     0.78      0.79
# SGDClassifier                      0.74               0.76     0.76      0.75
# ExtraTreeClassifier                0.74               0.74     0.74      0.75
# LabelSpreading                     0.75               0.74     0.74      0.75
# LabelPropagation                   0.75               0.73     0.73      0.75
# Perceptron                         0.71               0.72     0.72      0.71
# PassiveAggressiveClassifier        0.67               0.66     0.66      0.68
# DummyClassifier                    0.63               0.50     0.50      0.49
#
#                                Time Taken
# Model
# XGBClassifier                        0.14
# AdaBoostClassifier                   0.16
# LGBMClassifier                       0.11
# KNeighborsClassifier                 0.04
# RandomForestClassifier               0.32
# SVC                                  0.04
# NuSVC                                0.04
# ExtraTreesClassifier                 0.24
# BaggingClassifier                    0.07
# NearestCentroid                      0.02
# LogisticRegression                   0.02
# QuadraticDiscriminantAnalysis        0.03
# LinearSVC                            0.06
# DecisionTreeClassifier               0.02
# LinearDiscriminantAnalysis           0.09
# GaussianNB                           0.02
# RidgeClassifier                      0.03
# RidgeClassifierCV                    0.02
# CalibratedClassifierCV               0.20
# BernoulliNB                          0.02
# SGDClassifier                        0.02
# ExtraTreeClassifier                  0.02
# LabelSpreading                       0.17
# LabelPropagation                     0.13
# Perceptron                           0.02
# PassiveAggressiveClassifier          0.02
# DummyClassifier                      0.02

# %% [markdown]
# ### XGBClassifier produce best accuracy 0.85 for this data

# %% [markdown]
# # 4 Model Training

# %% [markdown]
# ## 4.1 XGBClassifier

# %%
model=XGBClassifier()
model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
print('Training accuracy of the model:',model.score(X_train,y_train))
# Out:
# Training accuracy of the model: 1.0

# %%
print('Testing accuracy of the model:',accuracy_score(y_test,model.predict(X_test)))
# Out:
# Testing accuracy of the model: 0.8470149253731343

# %% [markdown]
# ### 4.1.1 HyperParameter Tuning using OPTUNA

# %%
## define a objective function to optimize
def objective(trail):
    params={
        'max_depth':trail.suggest_int('max_depth',3,10),
        'learning_rate':trail.suggest_loguniform('learning_rate',0.001,0.1),
        'n_estimators':trail.suggest_int('n_estimators',100,1000),
        'subsample':trail.suggest_float('subsample',0.5,1),
        'colsample_bytree':trail.suggest_float('colsample_bytree',0.5,1),
    }
    
    model=XGBClassifier(**params)
    
    model.fit(X_train,y_train)
    
    y_pred=model.predict(X_test)
    
    accuracy=accuracy_score(y_test,y_pred)
    
    return accuracy

# %%
study=optuna.create_study(direction='maximize')
study.optimize(objective,n_trials=50)
study.best_trial
# Out:
# [I 2024-05-07 08:52:18,927] A new study created in memory with name: no-name-fc46b2af-3492-4c56-b674-e616ffc69384
# [I 2024-05-07 08:52:19,446] Trial 0 finished with value: 0.8507462686567164 and parameters: {'max_depth': 6, 'learning_rate': 0.006777431112069304, 'n_estimators': 623, 'subsample': 0.5188977845507314, 'colsample_bytree': 0.7549809060628453}. Best is trial 0 with value: 0.8507462686567164.
. Best is trial 11 with value: 0.8805970149253731.
# [I 2024-05-07 08:52:33,729] Trial 42 finished with value: 0.8694029850746269 and parameters: {'max_depth': 10, 'learning_rate': 0.010426056518404671, 'n_estimators': 136, 'subsample': 0.969940417924572, 'colsample_bytree': 0.6466165997076625}. Best is trial 11 with value: 0.8805970149253731.
# [I 2024-05-07 08:52:33,913] Trial 43 finished with value: 0.8768656716417911 and parameters: {'max_depth': 9, 'learning_rate': 0.015119064746305581, 'n_estimators': 102, 'subsample': 0.9351033741058841, 'colsample_bytree': 0.681265363698457}. Best is trial 11 with value: 0.8805970149253731.
# [I 2024-05-07 08:52:34,100] Trial 44 finished with value: 0.8843283582089553 and parameters: {'max_depth': 9, 'learning_rate': 0.019354225003932343, 'n_estimators': 101, 'subsample': 0.9352226850816184, 'colsample_bytree': 0.6905130742434157}. Best is trial 44 with value: 0.8843283582089553.
# [I 2024-05-07 08:52:34,815] Trial 45 finished with value: 0.8432835820895522 and parameters: {'max_depth': 9, 'learning_rate': 0.02996490422058487, 'n_estimators': 780, 'subsample': 0.929491371143107, 'colsample_bytree': 0.7050504547521371}. Best is trial 44 with value: 0.8843283582089553.
# [I 2024-05-07 08:52:35,129] Trial 46 finished with value: 0.8395522388059702 and parameters: {'max_depth': 10, 'learning_rate': 0.022992417818803203, 'n_estimators': 210, 'subsample': 0.8504349153125497, 'colsample_bytree': 0.8007394121769621}. Best is trial 44 with value: 0.8843283582089553.
# [I 2024-05-07 08:52:35,367] Trial 47 finished with value: 0.8694029850746269 and parameters: {'max_depth': 9, 'learning_rate': 0.01855675710174599, 'n_estimators': 139, 'subsample': 0.9779645872099625, 'colsample_bytree': 0.6919515468191269}. Best is trial 44 with value: 0.8843283582089553.
# [I 2024-05-07 08:52:35,723] Trial 48 finished with value: 0.8432835820895522 and parameters: {'max_depth': 7, 'learning_rate': 0.0325468657303258, 'n_estimators': 322, 'subsample': 0.9106903394743081, 'colsample_bytree': 0.7518996860496612}. Best is trial 44 with value: 0.8843283582089553.
# [I 2024-05-07 08:52:35,946] Trial 49 finished with value: 0.8656716417910447 and parameters: {'max_depth': 5, 'learning_rate': 0.013734682746728365, 'n_estimators': 246, 'subsample': 0.6330193258955964, 'colsample_bytree': 0.6590072743153449}. Best is trial 44 with value: 0.8843283582089553.
# FrozenTrial(number=44, state=TrialState.COMPLETE, values=[0.8843283582089553], datetime_start=datetime.datetime(2024, 5, 7, 8, 52, 33, 916690), datetime_complete=datetime.datetime(2024, 5, 7, 8, 52, 34, 100150), params={'max_depth': 9, 'learning_rate': 0.019354225003932343, 'n_estimators': 101, 'subsample': 0.9352226850816184, 'colsample_bytree': 0.6905130742434157}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=10, log=False, low=3, step=1), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None), 'n_estimators': IntDistribution(high=1000, log=False, low=100, step=1), 'subsample': FloatDistribution(high=1.0, log=False, low=0.5, step=None), 'colsample_bytree': FloatDistribution(high=1.0, log=False, low=0.5, step=None)}, trial_id=44, value=None)

# %%
best_params=study.best_trial.params

# %%
tuned_model=XGBClassifier(**best_params)
tuned_model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.6905130742434157, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.019354225003932343,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=9, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=101, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
print('Training accuracy of the model:',tuned_model.score(X_train,y_train))
# Out:
# Training accuracy of the model: 0.9406099518459069

# %%
print('Testing accuracy of the model:',accuracy_score(y_test,tuned_model.predict(X_test)))
# Out:
# Testing accuracy of the model: 0.8843283582089553

# %% [markdown]
# # 5 Prediction

# %%
test_df=pd.read_csv('/kaggle/input/titanic/test.csv')
test_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket   Fare Cabin Embarked
# 0      male 34.50      0      0              330911   7.83   NaN        Q
# 1    female 47.00      1      0              363272   7.00   NaN        S
# 2      male 62.00      0      0              240276   9.69   NaN        Q
# 3      male 27.00      0      0              315154   8.66   NaN        S
# 4    female 22.00      1      1             3101298  12.29   NaN        S
# ..      ...   ...    ...    ...                 ...    ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236   8.05   NaN        S
# 414  female 39.00      0      0            PC 17758 108.90  C105        C
# 415    male 38.50      0      0  SOTON/O.Q. 3101262   7.25   NaN        S
# 416    male   NaN      0      0              359309   8.05   NaN        S
# 417    male   NaN      1      1                2668  22.36   NaN        C
#
# [418 rows x 11 columns]

# %%
test_df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test_df['Fare'].describe()
# Out:
# count   417.00
# mean     35.63
# std      55.91
# min       0.00
# 25%       7.90
# 50%      14.45
# 75%      31.50
# max     512.33
# Name: Fare, dtype: float64

# %%
test_df.fillna({'Age':test_df['Age'].median()},inplace=True)
test_df.fillna({'Cabin':test_df['Cabin'].mode().iloc[0]},inplace=True)
test_df.fillna({'Fare':test_df['Fare'].median()},inplace=True)
test_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket   Fare            Cabin  \
# 0      male 34.50      0      0              330911   7.83  B57 B59 B63 B66
# 1    female 47.00      1      0              363272   7.00  B57 B59 B63 B66
# 2      male 62.00      0      0              240276   9.69  B57 B59 B63 B66
# 3      male 27.00      0      0              315154   8.66  B57 B59 B63 B66
# 4    female 22.00      1      1             3101298  12.29  B57 B59 B63 B66
# ..      ...   ...    ...    ...                 ...    ...              ...
# 413    male 27.00      0      0           A.5. 3236   8.05  B57 B59 B63 B66
# 414  female 39.00      0      0            PC 17758 108.90             C105
# 415    male 38.50      0      0  SOTON/O.Q. 3101262   7.25  B57 B59 B63 B66
# 416    male 27.00      0      0              359309   8.05  B57 B59 B63 B66
# 417    male 27.00      1      1                2668  22.36  B57 B59 B63 B66
#
#     Embarked
# 0          Q
# 1          S
# 2          Q
# 3          S
# 4          S
# ..       ...
# 413        S
# 414        C
# 415        S
# 416        S
# 417        C
#
# [418 rows x 11 columns]

# %%
test_df.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
result=pd.DataFrame(test_df['PassengerId'])

# %%
test_df=test_df.apply(lambda data:label_encoder(data))
test_df
# Out:
#      PassengerId  Pclass  Name  Sex   Age  SibSp  Parch  Ticket   Fare  Cabin  \
# 0            892       3   206    1 34.50      0      0     152   7.83     15
# 1            893       3   403    0 47.00      1      0     221   7.00     15
# 2            894       2   269    1 62.00      0      0      73   9.69     15
# 3            895       3   408    1 27.00      0      0     147   8.66     15
# 4            896       3   178    0 22.00      1      1     138  12.29     15
# ..           ...     ...   ...  ...   ...    ...    ...     ...    ...    ...
# 413         1305       3   353    1 27.00      0      0     267   8.05     15
# 414         1306       1   283    0 39.00      0      0     324 108.90     22
# 415         1307       3   332    1 38.50      0      0     346   7.25     15
# 416         1308       3   384    1 27.00      0      0     220   8.05     15
# 417         1309       3   302    1 27.00      1      1     105  22.36     15
#
#      Embarked
# 0           1
# 1           2
# 2           1
# 3           2
# 4           2
# ..        ...
# 413         2
# 414         0
# 415         2
# 416         2
# 417         0
#
# [418 rows x 11 columns]

# %%
y_pred=tuned_model.predict(test_df)
result['Survived']=y_pred
result
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
result.to_csv('Submission.csv',index=False)
